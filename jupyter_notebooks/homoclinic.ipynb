# %% [markdown]
# # Homoclinic Orbit
#
# ![homoclinic](../pics/homoclinic.png)
# $
# \left\{
# \begin{array}{l}
# \dot{x}=y
# \\
# \dot{y} = x - x^3
# \end{array}
# \right.
# $

# %%
# this makes sure it starts looking for things from the top folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\ode_to_odes

# %%
from ode_helpers import *

# %%
def f(t, y, c):
    ydot = [y[1],
         y[0] - y[0]**3]
    return ydot

def dx_dt(x, y):
    return f(0, (x, y), c)[0]
    
def dy_dt(x, y):
    return f(0, (x, y), c)[1]

c= 0

# %%
plot_phase_plane(dx_dt,
                 dy_dt,
                 x_range=(-2,2),
                 y_range=(-2,2),
                 mesh_density=20,
                 scale=20,
                 stream_density=1,
                 # %trajectories=[(2, 0), (-2, 1), (0, -2)]
                 )
