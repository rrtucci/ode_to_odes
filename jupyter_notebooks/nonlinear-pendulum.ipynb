# %% [markdown]
# # Nonlinear Pendulum
#
# https://github.com/phaseportrait/phaseportrait
#
# $
# \left\{\begin{array}{l}
# \dot{\theta}= v
# \\
# \dot{v} = - sin(\theta)
# \end{array}
# \right.$

# %%
# this makes sure it starts looking for things from the top folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\ode_to_odes

# %%
from ode_helpers import *
from phaseportrait import PhasePortrait2D

# %%
def ydot(theta, v):
    return v, -np.sin(theta)

pp = PhasePortrait2D(
    ydot, [-9, 9], MeshDim=21, Title='Nonlinear pendulum', xlabel=r"$\Theta$", ylabel=r"$\dot{\Theta}$")
pp.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: title={'center': 'Nonlinear pendulum'}, xlabel='$\\Theta$', ylabel='$\\dot{\\Theta}$'>)

# %%
def f(t, y, c):
    return [y[1], -np.sin(y[0])]

def dx_dt(x, y):
    return f(0, (x, y), c)[0]
    
def dy_dt(x, y):
    return f(0, (x, y), c)[1]

c=0

# %%
plot_phase_plane(dx_dt,
                 dy_dt,
                 x_range=(-9, 9),
                 y_range=(-4, 4),
                 mesh_density=20,
                 scale=20,
                 stream_density=1
                 # %trajectories=[(2, 0), (-2, 1), (0, -2)]
                 )
