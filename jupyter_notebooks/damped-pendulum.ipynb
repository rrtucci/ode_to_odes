# %% [markdown]
# # Damped Pendulum
#
# $\dot{\theta}= - sin(\theta)$

# %%
# this makes sure it starts looking for things from the top folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\ode_to_odes

# %%
from matplotlib import pyplot
import numpy as np

from phaseportrait import PhasePortrait2D

def dFPendulum(theta, v):
    return v, -np.sin(theta)

SimplePendulum = PhasePortrait2D(dFPendulum, [-9, 9], MeshDim=21, Title='Simple pendulum', xlabel=r"$\Theta$", ylabel=r"$\dot{\Theta}$")
SimplePendulum.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: title={'center': 'Simple pendulum'}, xlabel='$\\Theta$', ylabel='$\\dot{\\Theta}$'>)
