# %% [markdown]
# # Heteroclinic Orbit
#
# $
# \left\{
# \begin{array}{l}
# \dot{x}= y - y^3
# \\
# \dot{y}=-x - y^2
# \end{array}
# \right.
# $
#
# A heteroclinic has a cycle which contains two
#  saddle point fixed points. An object can
#  enter the orbit  through one
#  saddle point and leave through the other.

# %%
# this makes sure it starts looking for things from the top folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\ode_to_odes

# %%
from ode_helpers import *

# %%
def f(t, y, c):
    ydot = [y[1]-y[1]**3,
         -y[0] - y[1]**2]
    return ydot

def dx_dt(x, y):
    return f(0, (x, y), c)[0]
    
def dy_dt(x, y):
    return f(0, (x, y), c)[1]

c= 0

# %%
plot_phase_plane(dx_dt,
                 dy_dt,
                 x_range=(-2,2),
                 y_range=(-2,2),
                 mesh_density=20,
                 scale=20,
                 stream_density=1,
                 # %trajectories=[(2, 0), (-2, 1), (0, -2)]
                 )
